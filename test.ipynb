# %% [markdown]
# <a href="https://colab.research.google.com/github/WKowalczykDev/blind-iqa-resolution-cnn/blob/main/pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TESTOWANIE POŁĄCZENIA VSCODE

# %%
print("xd")

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
FOLDER_ID = '1sSs_cneHbA8i2XZpq7SIZsHGwnWDloL3'
FOLDER_NAME = 'UMwTi'  # ta sama co w Drive
path = f'/content/drive/.shortcut-targets-by-id/{FOLDER_ID}/{FOLDER_NAME}'

print(os.listdir(path))

# %%
# !ls -la /content/Real-ESRGAN
# Out:
# total 176
# drwxr-xr-x 15 root root  4096 Apr 27 16:12 .
# drwxr-xr-x  1 root root  4096 Apr 27 16:12 ..
# drwxr-xr-x  2 root root  4096 Apr 27 16:12 assets
# -rw-r--r--  1 root root  5251 Apr 27 16:12 CODE_OF_CONDUCT.md
# -rw-r--r--  1 root root  6688 Apr 27 16:12 cog_predict.py
# -rw-r--r--  1 root root   485 Apr 27 16:12 cog.yaml
# drwxr-xr-x  2 root root  4096 Apr 27 16:12 docs
# drwxr-xr-x  3 root root  4096 Apr 27 16:12 experiments
# drwxr-xr-x  8 root root  4096 Apr 27 16:12 .git
# drwxr-xr-x  3 root root  4096 Apr 27 16:12 .github
# -rw-r--r--  1 root root  1901 Apr 27 16:12 .gitignore
# -rw-r--r--  1 root root  7745 Apr 27 16:12 inference_realesrgan.py
# -rw-r--r--  1 root root 16910 Apr 27 16:12 inference_realesrgan_video.py
# drwxr-xr-x  3 root root  4096 Apr 27 16:12 inputs
# -rw-r--r--  1 root root  1519 Apr 27 16:12 LICENSE
# -rw-r--r--  1 root root   170 Apr 27 16:12 MANIFEST.in
# drwxr-xr-x  2 root root  4096 Apr 27 16:12 options
# -rw-r--r--  1 root root  1483 Apr 27 16:12 .pre-commit-config.yaml
# -rw-r--r--  1 root root 15779 Apr 27 16:12 README_CN.md
# -rw-r--r--  1 root root 16548 Apr 27 16:12 README.md
# drwxr-xr-x  6 root root  4096 Apr 27 16:25 realesrgan
# drwxr-xr-x  2 root root  4096 Apr 27 16:36 realesrgan.egg-info
# -rw-r--r--  1 root root   100 Apr 27 16:12 requirements.txt
# drwxr-xr-x  2 root root  4096 Apr 27 16:12 scripts
# -rw-r--r--  1 root root   684 Apr 27 16:12 setup.cfg
# -rw-r--r--  1 root root  3145 Apr 27 16:12 setup.py
# drwxr-xr-x  3 root root  4096 Apr 27 16:12 tests
# -rw-r--r--  1 root root     6 Apr 27 16:12 VERSION
# drwxr-xr-x  2 root root  4096 Apr 27 16:12 .vscode
# drwxr-xr-x  2 root root  4096 Apr 27 16:12 weights

# %%
import subprocess, psutil, shutil
print("GPU:", subprocess.getoutput("nvidia-smi -L") or "brak")
print(f"RAM: {psutil.virtual_memory().total / 1e9:.1f} GB")
print(f"Dysk: {shutil.disk_usage('/').total / 1e9:.1f} GB")
