# %% [markdown]
# # Montowanie Google Drive

# %% [markdown]
# ## KROK 1 — Montowanie Google Drive
#
# Montuje Google Drive i ustawia zmienną `path` wskazującą na folder ze zdjęciami.
# Jeśli zmieniasz lokalizację datasetu, zaktualizuj `FOLDER_ID` i `FOLDER_NAME`.

# %%
import os
import zipfile
import shutil

# --- KONFIGURACJA ŚCIEŻEK ---
FOLDER_LINK = "1sm0X1rhgh8qqYiqQw55Sbcm3kDKt239x"
TARGET_DIR = "/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/1K"

# 1. Przygotowanie czystego środowiska
os.makedirs(TARGET_DIR, exist_ok=True)
print(f"Folder docelowy przygotowany: {TARGET_DIR}")

print("Uruchamianie bezpiecznego pobierania z Google Drive...")
url = f"https://drive.google.com/drive/u/0/folders/{FOLDER_LINK}"
cmd = f"gdown --folder --continue '{url}' -O '{TARGET_DIR}'"

# Wywołanie komendy systemowej
os.system(cmd)

print("\nSprawdzanie zawartości i ewentualne rozpakowywanie...")

# 3. Automatyczny strażnik ZIP-ów 
# Jeśli Google podmieni folder na ZIP-a lub pobierze archiwum, skrypt to wykryje
for item in os.listdir(TARGET_DIR):
    item_path = os.path.join(TARGET_DIR, item)
    
    if item.endswith(".zip") and os.path.isfile(item_path):
        print(f"📦 Wykryto archiwum ZIP: {item}. Rozpakowywanie do {TARGET_DIR}...")
        try:
            with zipfile.ZipFile(item_path, 'r') as zip_ref:
                zip_ref.extractall(TARGET_DIR)
            os.remove(item_path)  # Usunięcie zipa po sukcesie, aby oszczędzić 2GB+ na dysku
            print("Archiwum rozpakowane pomyślnie, plik ZIP usunięty.")
        except Exception as e:
            print(f"❌ Błąd podczas rozpakowywania {item}: {e}")

# 4. Raport końcowy
all_files = os.listdir(TARGET_DIR)
nef_files = [f for f in all_files if f.lower().endswith('.nef')]

print('\n' + '=' * 50)
print(f"   PODSUMOWANIE PROCESU:")
print(f"   Lokalizacja: {TARGET_DIR}")
print(f"   Znalezionych plików .NEF: {len(nef_files)} / 1000")
print(f"   Wszystkich obiektów w folderze: {len(all_files)}")
print('=' * 50)

# %% [markdown]
# ## KROK 2 — Instalacja zależności i pobieranie wag modeli
#
# Instaluje wszystkie pakiety Pythona i klonuje Real-ESRGAN z GitHub (instalacja z PyPI nie udostępnia modułu `realesrgan`).
# Nakłada patch na `basicsr` dla kompatybilności z torchvision ≥ 0.17 (`functional_tensor` zostało usunięte).
# Pobiera wagi sieci do `/content/weights/` i sprawdza ich poprawność (rozmiar > 1 MB — strona błędu wget ma kilka KB).

# %%
import os, sys, glob, subprocess

# --- Instalacja pakietów ---
os.system('pip install -q basicsr facexlib gfpgan')
os.system('pip install -q lpips pytorch-msssim scikit-image')
os.system('pip install -q rawpy')

# --- Real-ESRGAN z repozytorium ---
if not os.path.exists('/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/Real-ESRGAN'):
    subprocess.run(['git', 'clone', 'https://github.com/xinntao/Real-ESRGAN.git',
                    '/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/Real-ESRGAN'], check=True)

os.chdir('/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/Real-ESRGAN')
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-r', 'requirements.txt'], check=True)
subprocess.run([sys.executable, 'setup.py', 'develop', '--quiet'], check=True)
os.chdir('/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/')

if '/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/Real-ESRGAN' not in sys.path:
    sys.path.insert(0, '/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/Real-ESRGAN')

print('✅ Zależności zainstalowane')

# --- Patch basicsr: torchvision >= 0.17 usunęło functional_tensor ---
patched = 0
for filepath in glob.glob('/usr/local/lib/python3.12/dist-packages/basicsr/**/*.py', recursive=True):
    try:
        with open(filepath, 'r') as f:
            content = f.read()
        if 'from torchvision.transforms.functional_tensor import' in content:
            content = content.replace(
                'from torchvision.transforms.functional_tensor import',
                'from torchvision.transforms.functional import'
            )
            with open(filepath, 'w') as f:
                f.write(content)
            patched += 1
    except Exception:
        pass
print(f'✅ basicsr patch zastosowany ({patched} plik/pliki)')

# --- Wagi modeli ---
os.makedirs('/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/weights', exist_ok=True)

def is_valid_pth(path):
    return os.path.exists(path) and os.path.getsize(path) > 1024 * 1024

def download_weight(filename, url):
    path = f'/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/weights/{filename}'
    if not is_valid_pth(path):
        if os.path.exists(path):
            os.remove(path)
        ret = os.system(f'wget -q -O {path} {url}')
        print(f'{"✅" if ret==0 and is_valid_pth(path) else "❌"} {filename}')
    else:
        print(f'{filename} już istnieje')

download_weight('RealESRGAN_x4plus.pth',
    'https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth')
download_weight('RRDB_ESRGAN_x4.pth',
    'https://huggingface.co/ai-forever/Real-ESRGAN/resolve/main/RealESRGAN_x4.pth')

print('\n✅ Wszystkie wagi gotowe')

# %% [markdown]
# ## KROK 3 — Konfiguracja pipeline'u
#
# **Jedyne miejsce do ręcznej edycji.** Ustaw tutaj:
# - `N` — limit zdjęć (`10` do sanity testu, `1000` do pełnego runu)
# - `INPUT_DIR` / `OUTPUT_DIR` — ścieżki wejścia i wyjścia
# - `SCALE_FACTORS` — współczynniki skalowania
# - `ENTROPY_MIN`, `NOISE_VAR_MAX` — progi filtrowania jakości patchy
# - `SPLIT_RATIO` — proporcje train/val/test
#
# Tworzy strukturę katalogów wyjściowych i zapisuje `pipeline_config.json`.

# %%
import os, json

path = '/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/'
INPUT_DIR  = os.path.join(path, '1K')
OUTPUT_DIR = os.path.join(path, 'K_out')

# --- Skala i kadrowanie ---
SCALE_FACTORS = [i+1 for i in range(10)]
CROP_SIZE     = 256   # środkowe wycięcie po pipeline
N_CANDIDATES  = 16    # ile kandydatów na obraz

# --- Filtry jakości patcha ---
ENTROPY_MIN   = 4.5   # minimalna entropia Shannona (bity)
NOISE_VAR_MAX = 2500  # max wariancja Laplaciana

# --- Splitowanie ---
SPLIT_RATIO = (0.70, 0.15, 0.15)   # train / val / test
SPLIT_SEED  = 42
# ID pary algorytmów, która ma NIE pojawiać się w zbiorze testowym
EXCLUDED_PAIR_FROM_TEST = 4  # Zmień na dowolne ID (0-10)
STRESS_TEST_KEYWORDS = [
    'szachownica', 'checker', 'ai_gen', 'render',
    'anime', 'rysunek', 'drawing',
]

# --- Limit ←── zmień na 10 do sanity testu, 1000 do pełnego runu ---
N = 10

extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp', '.nef')

# --- Struktura katalogów wyjściowych ---
for subdir in ('train', 'val', 'test', 'stress_test'):
    os.makedirs(os.path.join(OUTPUT_DIR, subdir), exist_ok=True)

MANIFEST_PATH = os.path.join(OUTPUT_DIR, 'manifest.jsonl')
SPLITS_PATH   = os.path.join(OUTPUT_DIR, 'splits.json')

pipeline_config = {
    'scale_factors':        SCALE_FACTORS,
    'crop_size':            CROP_SIZE,
    'n_candidates':         N_CANDIDATES,
    'entropy_min':          ENTROPY_MIN,
    'noise_var_max':        NOISE_VAR_MAX,
    'split_ratio':          list(SPLIT_RATIO),
    'split_seed':           SPLIT_SEED,
    'stress_test_keywords': STRESS_TEST_KEYWORDS,
    'n_limit':              N,
    'excluded': EXCLUDED_PAIR_FROM_TEST
}
with open(os.path.join(OUTPUT_DIR, 'pipeline_config.json'), 'w') as f:
    json.dump(pipeline_config, f, indent=2)

if not os.path.exists(INPUT_DIR):
    print(f'⚠️  Folder wejściowy nie istnieje: {INPUT_DIR}')

# %% [markdown]
# ## KROK 4 — Importy i sprawdzenie GPU
#
# Importuje biblioteki PyTorch, PIL, NumPy, OpenCV. Wykrywa dostępność GPU i ustawia zmienną `DEVICE` (`cuda` lub `cpu`).

# %%
import sys
import json
import time
import numpy as np
from PIL import Image, ImageFilter
import cv2
import torch
from pathlib import Path

# 1. Całkowite usunięcie obecnych wersji (czyścimy konfliktowe pakiety)
# !pip uninstall -y torch torchvision torchaudio xformers basicsr

# 2. Instalacja kompatybilnego zestawu pod CUDA 12.1 (wersje stabilne "jak z Colaba")
# !pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu121

# 3. Ponowna instalacja pakietów projektowych (pobiorą się już pod starszego PyTorcha)
# !pip install basicsr facexlib gfpgan lpips pytorch-msssim scikit-image rawpy

print(f'PyTorch: {torch.__version__}')
print(f'CUDA dostępna: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Urządzenie: {DEVICE}')

# %% [markdown]
# ## KROK 5 — Inicjalizacja modeli SR
#
# Ładuje dwa modele ESRGAN ×4 do pamięci GPU (wykonywane tylko raz na sesję):
# - **Real-ESRGAN** (`RealESRGAN_x4plus.pth`) — model z generatorem perceptualnym, wytrenowany na syntetycznych degradacjach
# - **ESRGAN classic** (`RRDB_ESRGAN_x4.pth`) — oryginalny ESRGAN z 2018 r., bliższy teksturom rzeczywistym

# %%
import sys
import os
import torch

# --- 1. AUTOMATYCZNE WYKRYWANIE URZĄDZENIA (Definicja DEVICE) ---
if torch.cuda.is_available():
    DEVICE = 'cuda'
    print(f"✅ Wykryto GPU: {torch.cuda.get_device_name(0)} -> Modele ruszą na karcie graficznej!")
else:
    DEVICE = 'cpu'
    print("⚠️ Nie wykryto GPU (wybierz CPU). Przetwarzanie będzie wolniejsze.")

# --- 2. DODANIE REPOZYTORIUM DO ŚCIEŻEK SYSTEMOWYCH ---
if '/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/Real-ESRGAN' not in sys.path:
    sys.path.insert(0, '/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/Real-ESRGAN')

# --- 3. NAPRAWA FORMATU CHECKPOINTÓW ---
def fix_checkpoint(path):
    ckpt = torch.load(path, map_location='cpu')
    if not isinstance(ckpt, dict) or ('params' not in ckpt and 'params_ema' not in ckpt):
        torch.save({'params': ckpt}, path)
        print(f'  ⚙️  Naprawiono format wag: {os.path.basename(path)}')

fix_checkpoint('/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/weights/RRDB_ESRGAN_x4.pth')

# --- 4. IMPORTY (Po zastosowaniu wcześniejszych patchy) ---
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet

# Modele zawsze działają w trybie x4; skalowanie do docelowego SF odbywa się w _esrgan_enhance
_MODEL_SCALE = 4

# --- 5. INICJALIZACJA MODELU: Real-ESRGAN ---
print("⏳ Ładowanie Real-ESRGAN...")
realesrgan_model = RRDBNet(
    num_in_ch=3, num_out_ch=3, num_feat=64,
    num_block=23, num_grow_ch=32, scale=_MODEL_SCALE
)
realesrgan_upsampler = RealESRGANer(
    scale=_MODEL_SCALE,
    model_path='/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/weights/RealESRGAN_x4plus.pth',
    model=realesrgan_model,
    tile=0, tile_pad=10, pre_pad=0,
    half=(DEVICE == 'cuda')  # Teraz DEVICE jest już znane!
)
print('✅ Real-ESRGAN załadowany pomyślnie.')

# --- 6. INICJALIZACJA MODELU: ESRGAN classic ---
print("⏳ Ładowanie ESRGAN classic...")
esrgan_classic_model = RRDBNet(
    num_in_ch=3, num_out_ch=3, num_feat=64,
    num_block=23, num_grow_ch=32, scale=_MODEL_SCALE
)
esrgan_classic_upsampler = RealESRGANer(
    scale=_MODEL_SCALE,
    model_path='/mnt/DyskDodatkowyEXT4/blindIQA_wojnar/weights/RRDB_ESRGAN_x4.pth',
    model=esrgan_classic_model,
    tile=0, tile_pad=10, pre_pad=0,
    half=(DEVICE == 'cuda')
)
print('✅ ESRGAN classic załadowany pomyślnie.')

# %% [markdown]
# ## KROK 5b — Deterministyczny podział na zbiory
#
# Przypisuje każdy plik źródłowy do jednego zbioru **przed** przetwarzaniem — eliminuje przecieki (ten sam obraz nie trafi jednocześnie do train i test).
#
# - Pliki zawierające słowa z `STRESS_TEST_KEYWORDS` w nazwie → `stress_test` (zdjęcia syntetyczne, rendery)
# - Pozostałe → przetasowane z `SPLIT_SEED=42`, podzielone wg `SPLIT_RATIO` (domyślnie 70/15/15)
#
# Wynik zapisywany do `splits.json`.

# %%
import hashlib, random, json

def _sha1(s: str) -> str:
    return hashlib.sha1(s.encode()).hexdigest()

# Zlistuj pliki (do limitu N)
all_files = sorted([
    f for f in os.listdir(INPUT_DIR)
    if f.lower().endswith(extensions)
])[:N]

# Przypisz stress_test po słowach kluczowych, resztę losuj
stress_kw = [k.lower() for k in STRESS_TEST_KEYWORDS]
regular, stress = [], []
for f in all_files:
    if any(kw in f.lower() for kw in stress_kw):
        stress.append(f)
    else:
        regular.append(f)

rng_split = random.Random(SPLIT_SEED)
shuffled  = regular.copy()
rng_split.shuffle(shuffled)

n       = len(shuffled)
n_train = int(n * SPLIT_RATIO[0])
n_val   = int(n * SPLIT_RATIO[1])

assignments = {}
for f in shuffled[:n_train]:              assignments[f] = 'train'
for f in shuffled[n_train:n_train+n_val]: assignments[f] = 'val'
for f in shuffled[n_train+n_val:]:        assignments[f] = 'test'
for f in stress:                           assignments[f] = 'stress_test'

counts = {s: sum(1 for v in assignments.values() if v == s)
          for s in ('train', 'val', 'test', 'stress_test')}

splits_data = {
    'seed': SPLIT_SEED, 'ratio': list(SPLIT_RATIO),
    'assignments': assignments, 'counts': counts,
}
with open(SPLITS_PATH, 'w') as f:
    json.dump(splits_data, f, indent=2)

def get_split(filename: str) -> str:
    return assignments.get(filename, 'test')

print(f'✅ Splits zapisane → {SPLITS_PATH}')
for s, c in counts.items():
    print(f'   {s:15s}: {c}')

# %% [markdown]
# ### KROK 6 — Funkcje przetwarzania i pary algorytmów
#
# W tym kroku zdefiniowano funkcje pomocnicze do manipulacji obrazem oraz zestawienie **10 par algorytmów** (plus klasa kontrolna). Pary te łączą różne metody degradacji (downscaling) z metodami restauracji (upscaling), aby umożliwić szczegółową analizę artefaktów – od klasycznej utraty jakości po halucynacje modeli AI.
#
# #### Zestawienie badanych par algorytmów
#
# | Para ID | Kategoria (Grupa) | Downscale (Degradacja) | Upscale (Restauracja) | Cel testu / Typ artefaktów |
# |:---:|:---|:---|:---|:---|
# | **0** | `oryginal_brak_kompresji` | *Identity* | *Identity* | Punkt odniesienia (Control) - brak zmian |
# | **1** | `czysty_aliasing` | Nearest Neighbor | Nearest Neighbor | Maksymalna pikseloza i ostre schodkowanie |
# | **2** | `rozmyty_aliasing` | Nearest Neighbor | Bicubic | Próba klasycznego wygładzenia pikselozy |
# | **3** | `brutalne_rozmycie` | Box Filter | Bicubic | Ekstremalna utrata detali i miękkie krawędzie |
# | **4** | `klasyczna_utrata_jakosci` | Bicubic | Bicubic | Standardowa, zrównoważona utrata wysokich częstotliwości |
# | **5** | `optymalne_klasyczne` | Lanczos | Bicubic | Najwyższa wierność pomniejszenia, klasyczny upscale |
# | **6** | `ai_vs_silny_aliasing` | Nearest Neighbor | Real-ESRGAN | Jak AI radzi sobie z twardymi, sztucznymi krawędziami |
# | **7** | `ai_vs_rozmycie` | Box Filter | ESRGAN classic | Próba odzyskania detali z całkowicie rozmytego obrazu |
# | **8** | `standardowe_halucynacje_ai`| Bicubic | Real-ESRGAN | Typowe zastosowanie AI (halucynacje i generowanie detali) |
# | **9** | `klasyczne_halucynacje_ai` | Bicubic | ESRGAN classic | Starsze AI próbujące wyostrzyć standardowe rozmycie |
# | **10**| `wysoka_wiernosc_ai` | Lanczos | ESRGAN classic | Najlepsze zachowanie detali przy użyciu klasycznego AI |
#
# #### Funkcje przetwarzania (Crop & Resize)
#
# * **`smart_crop`** — losuje `N_CANDIDATES` obszarów 320×320, filtruje według progu szumu i wybiera ten o najwyższej entropii Shannona. Jeśli żaden nie spełni warunków, awaryjnie wycina środek.
# * **`center_crop`** — wycina centralny obszar 256×256 z patcha 320×320 po procesie skalowania.
# * **Modele AI (`_esrgan_enhance`)** — natywnie działają w trybie ×4. Jeśli współczynnik skali (`sf`) jest

# %%
# ---- Downscaling (wszystkie: img, sf) ----

def downscale_identity(img, sf): return img  # Klasa kontrolna
def downscale_nearest(img, sf): w, h = img.size; return img.resize((w//sf, h//sf), Image.NEAREST)
def downscale_box(img, sf):     w, h = img.size; return img.resize((w//sf, h//sf), Image.BOX)
def downscale_bicubic(img, sf): w, h = img.size; return img.resize((w//sf, h//sf), Image.BICUBIC)
def downscale_lanczos(img, sf): w, h = img.size; return img.resize((w//sf, h//sf), Image.LANCZOS)

# ---- Upscaling (wszystkie: img, sf) ----

def upscale_identity(img, sf): return img  # Klasa kontrolna

def upscale_nearest(img, sf):
    w, h = img.size; return img.resize((w*sf, h*sf), Image.NEAREST)

def upscale_bicubic(img, sf):
    w, h = img.size; return img.resize((w*sf, h*sf), Image.BICUBIC)

def _esrgan_enhance(upsampler, img, sf):
    """Model zawsze robi x4; jeśli sf != 4, resize do sf*oryginał."""
    img_bgr  = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    out_bgr, _ = upsampler.enhance(img_bgr, outscale=4)
    out      = Image.fromarray(cv2.cvtColor(out_bgr, cv2.COLOR_BGR2RGB))
    tw, th   = img.size[0] * sf, img.size[1] * sf
    if out.size != (tw, th):
        out = out.resize((tw, th), Image.LANCZOS)
    return out

def upscale_realesrgan(img, sf):
    return _esrgan_enhance(realesrgan_upsampler, img, sf)

def upscale_esrgan_classic(img, sf):
    return _esrgan_enhance(esrgan_classic_upsampler, img, sf)

def esrgan_upscale_method(sf):
    return 'native_x4' if sf == 4 else 'native_x4_then_resize'

# ---- Pary algorytmów ----

PAIR_GROUPS = {
    0: 'oryginal_brak_kompresji',
    1: 'czysty_aliasing',
    2: 'rozmyty_aliasing',
    3: 'brutalne_rozmycie',
    4: 'klasyczna_utrata_jakosci',
    5: 'optymalne_klasyczne',
    6: 'ai_vs_silny_aliasing',
    7: 'ai_vs_rozmycie',
    8: 'standardowe_halucynacje_ai',
    9: 'klasyczne_halucynacje_ai',
    10: 'wysoka_wiernosc_ai'
}

ALGORITHM_PAIRS = [
    # 0: Klasa kontrolna
    {'pair_id': 0, 'down_name': 'Original (Control)', 'down_abbr': 'CTRL',
     'up_name': 'Original (Control)', 'up_abbr': 'CTRL',
     'downscale': downscale_identity, 'upscale': upscale_identity,
     'upscale_method': 'identity'},
     
    # 1: Czysty aliasing (schody)
    {'pair_id': 1, 'down_name': 'Nearest Neighbor', 'down_abbr': 'NN',
     'up_name': 'Nearest Neighbor', 'up_abbr': 'NN',
     'downscale': downscale_nearest, 'upscale': upscale_nearest,
     'upscale_method': 'native'},

    # 2: Aliasing wygładzony klasycznie
    {'pair_id': 2, 'down_name': 'Nearest Neighbor', 'down_abbr': 'NN',
     'up_name': 'Bicubic', 'up_abbr': 'BIC',
     'downscale': downscale_nearest, 'upscale': upscale_bicubic,
     'upscale_method': 'native'},

    # 3: Silne rozmycie bez prób wyostrzania
    {'pair_id': 3, 'down_name': 'Box Filter', 'down_abbr': 'BOX',
     'up_name': 'Bicubic', 'up_abbr': 'BIC',
     'downscale': downscale_box, 'upscale': upscale_bicubic,
     'upscale_method': 'native'},

    # 4: Standardowa strata jakości (baseline dla klasyki)
    {'pair_id': 4, 'down_name': 'Bicubic', 'down_abbr': 'BIC',
     'up_name': 'Bicubic', 'up_abbr': 'BIC',
     'downscale': downscale_bicubic, 'upscale': upscale_bicubic,
     'upscale_method': 'native'},

    # 5: Najlepszy klasyczny downscale + klasyczny upscale
    {'pair_id': 5, 'down_name': 'Lanczos', 'down_abbr': 'LANCZOS',
     'up_name': 'Bicubic', 'up_abbr': 'BIC',
     'downscale': downscale_lanczos, 'upscale': upscale_bicubic,
     'upscale_method': 'native'},

     {'pair_id': 6, 'down_name': 'Bicubic', 'down_abbr': 'BIC',
     'up_name': 'Real-ESRGAN', 'up_abbr': 'RESRGAN',
     'downscale': downscale_bicubic, 'upscale': upscale_realesrgan,
     'upscale_method': esrgan_upscale_method}, # Zamiast None, przekazujemy funkcję

]

print('✅ Smart crop i algorytmy gotowe')
for p in ALGORITHM_PAIRS:
    print(f"  Para {p['pair_id']}: {p['down_name']} → {p['up_name']}")

# %% [markdown]
# ## KROK 7 — Główna pętla pipeline'u
#
# Przetwarza N zdjęć RAW. Dla każdego pliku:
# 1. Otwiera plik NEF przez `rawpy` i konwertuje do RGB
# 2. Wybiera patch 320×320 przez `smart_crop`
# 3. Zapisuje oryginał 256×256 (center crop) jako PNG + wpis `type=oryginal` w manifeście
# 4. Dla każdego `sf` ∈ `SCALE_FACTORS` × 4 pary algorytmów:
#    - downscale patch → low-res
#    - upscale low-res → high-res 320×320
#    - center crop do 256×256
#    - oblicza PSNR, SSIM, MS-SSIM, LPIPS, pseudo_mos, cechy FFT
#    - zapisuje PNG + wpis `type=processed` w manifeście
#
# Łącznie `N × (1 + |SCALE_FACTORS| × |ALGORITHM_PAIRS|)` wpisów w manifeście.
#
# > **Uwaga:** manifest otwierany w trybie `append`. Przed ponownym uruchomieniem usuń stary plik `manifest.jsonl`.

# %%
import numpy as np
import torch
import cv2
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
from pytorch_msssim import ms_ssim as _ms_ssim
import lpips as _lpips_lib

# --- LPIPS model (ładowany raz) ---
_lpips_model = _lpips_lib.LPIPS(net='alex').to(DEVICE)
_lpips_model.eval()
print('✅ LPIPS (alex) załadowany')

# --- Cechy no-reference (NR): model widzi tylko zdegradowany obraz ---
import numpy as np
import cv2
from PIL import Image

# --- 1. SZYBKIE FUNKCJE METRYK (na patchach w skali szarości) ---

def shannon_entropy_8bit(gray_arr: np.ndarray) -> float:
    """Oblicza entropię Shannona - mówi nam, jak dużo informacji/szczegółów jest w kadrze."""
    # Szybki histogram z użyciem numpy
    hist, _ = np.histogram(gray_arr, bins=256, range=(0, 256))
    p = hist / (hist.sum() + 1e-12)
    p = p[p > 0]
    return float(-np.sum(p * np.log2(p)))

def laplacian_variance(gray_arr: np.ndarray) -> float:
    """Wariancja Laplasjanu - wykrywa ostrość i ilość szumu."""
    lap = cv2.Laplacian(gray_arr, cv2.CV_64F)
    return float(lap.var())

def mean_gradient_sobel(gray_arr: np.ndarray) -> float:
    """Średni gradient Sobela - mówi nam, jak wyraźne są krawędzie."""
    sx = cv2.Sobel(gray_arr, cv2.CV_64F, 1, 0, ksize=3)
    sy = cv2.Sobel(gray_arr, cv2.CV_64F, 0, 1, ksize=3)
    return float(np.sqrt(sx**2 + sy**2).mean())

# --- 2. GŁÓWNA FUNKCJA SMART CROP ---

def smart_crop(img_pil: Image.Image, crop_size: int, 
               n_candidates: int, ent_min: float, noise_var_max: float, rng) -> dict:
    """
    Losuje n_candidates obszarów, ocenia je pod kątem bogactwa detali i zwraca najlepszy.
    """
    w, h = img_pil.size
    
    # Zabezpieczenie: jeśli obraz bazowy jest mniejszy niż docelowy patch
    if w < crop_size or h < crop_size:
        img_pil = img_pil.resize((max(w, crop_size), max(h, crop_size)), Image.LANCZOS)
        w, h = img_pil.size

    candidates = []

    # 1. Losowanie i ewaluacja kandydatów
    for _ in range(n_candidates):
        x = rng.randint(0, w - crop_size)
        y = rng.randint(0, h - crop_size)
        
        # Wycinamy kandydata
        patch_pil = img_pil.crop((x, y, x + crop_size, y + crop_size))
        
        # Konwersja na grayscale do szybkiego policzenia metryk
        patch_arr = np.array(patch_pil)
        if patch_arr.ndim == 3:
            gray = cv2.cvtColor(patch_arr, cv2.COLOR_RGB2GRAY)
        else:
            gray = patch_arr
            
        # Obliczanie metryk
        ent = shannon_entropy_8bit(gray)
        var = laplacian_variance(gray)
        grad = mean_gradient_sobel(gray)
        
        candidates.append({
            'patch_pil': patch_pil,
            'coords': (x, y),
            'entropy': ent,
            'noise_var': var,
            'mean_gradient': grad
        })

    # 2. Filtrowanie (odrzucamy płaskie niebo i skrajny szum)
    valid_candidates = [
        c for c in candidates 
        if c['entropy'] >= ent_min and c['noise_var'] <= noise_var_max
    ]
    
    # 3. Wybór najlepszego (sortujemy głównie po entropii)
    fallback_used = False
    if valid_candidates:
        best_candidate = max(valid_candidates, key=lambda c: c['entropy'])
    else:
        # FALLBACK: Jeśli żaden nie spełnia warunków, bierzemy po prostu ten
        # z największą entropią z całej wylosowanej puli, by nie zepsuć pipeline'u.
        fallback_used = True
        best_candidate = max(candidates, key=lambda c: c['entropy'])

    best_patch = best_candidate['patch_pil']

    return {
        'patch_pil': best_patch,
        'top_left_xy': best_candidate['coords'],
        'entropy': best_candidate['entropy'],
        'noise_var': best_candidate['noise_var'],
        'mean_gradient': best_candidate['mean_gradient'],
        'fallback_used': fallback_used,
        'candidates_evaluated': n_candidates
    }

def patch_stats(img_rgb_uint8) -> dict:
    """3 NR cechy na obrazie szarościowym: entropia, wariancja Laplaciana, średni gradient."""
    if img_rgb_uint8.ndim == 3:
        gray = cv2.cvtColor(img_rgb_uint8, cv2.COLOR_RGB2GRAY)
    else:
        gray = img_rgb_uint8

    hist, _ = np.histogram(gray, bins=256, range=(0, 256))
    p = hist / (hist.sum() + 1e-12)
    p = p[p > 0]
    entropy = float(-np.sum(p * np.log2(p)))

    lap = cv2.Laplacian(gray, cv2.CV_64F)
    noise_var = float(lap.var())

    sx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    sy = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
    mean_grad = float(np.sqrt(sx**2 + sy**2).mean())

    return {
        'entropy_bits':        round(entropy,   4),
        'noise_var_laplacian': round(noise_var, 4),
        'mean_gradient':       round(mean_grad, 4),
    }

print('✅ patch_stats() gotowe')

# %%
import os
import json
import hashlib
import random
from datetime import datetime, timezone
from time import time
from PIL import Image
import numpy as np
import gc
import torch
from collections import Counter

# --- 1. FUNKCJE POMOCNICZE (ZINTEGROWANE I POPRAWIONE) ---

# def get_split(filename):
#     "

def load_base_image(path):
    """Bezpieczne ładowanie zarówno RAWów (.NEF) jak i zwykłych formatów."""
    if path.lower().endswith(('.raw', '.dng', '.cr2', '.nef', '.arw')):
        import rawpy
        with rawpy.imread(path) as raw:
            rgb = raw.postprocess()
        return Image.fromarray(rgb)
    else:
        return Image.open(path).convert('RGB')

def center_crop(img, x, y, target_size):
    return img.crop((x, y, x + target_size, y + target_size))

# --- 2. GŁÓWNA PĘTLA PIPELINE'U Z LOCAL CHECKPOINTAMI ---

print('=' * 60)
print(f'🚀 Start generacji zbioru danych (Limit: {N} zdjęć)')
print(f'📄 Target Manifest na dysku: {MANIFEST_PATH}')
print('=' * 60)

# Upewniamy się, że foldery wyjściowe fizycznie istnieją na naszym dysku lokalnym
os.makedirs(OUTPUT_DIR, exist_ok=True)
for folder in ('train', 'val', 'test', 'stress_test'):
    os.makedirs(os.path.join(OUTPUT_DIR, folder), exist_ok=True)

# --- 🔍 CZĘŚĆ A: ODCZYT CHECKPOINTU (ZAPOBIEGA POWTÓRKOM PRACY) ---
processed_source_files = set()
if os.path.exists(MANIFEST_PATH):
    print("🔄 Znaleziono istniejący manifest. Wczytywanie ukończonego postępu...")
    try:
        with open(MANIFEST_PATH, 'r', encoding='utf-8') as f:
            for line in f:
                if line.strip():
                    try:
                        record = json.loads(line)
                        if 'source_file' in record:
                            # Zapamiętujemy, że to zdjęcie zostało już w pełni przetworzone
                            processed_source_files.add(record['source_file'])
                    except json.JSONDecodeError:
                        continue
        print(f"✅ Odczytano checkpoint: pomijamy {len(processed_source_files)} ukończonych wcześniej zdjęć.")
    except Exception as e:
        print(f"⚠️ Nie udało się odczytać checkpointu ({e}), zaczynamy od zera.")

# Pobieramy pełną listę plików z wejściowego katalogu
base_image_files = sorted([f for f in os.listdir(INPUT_DIR) if f.lower().endswith(extensions)])[:N]
total_images = len(base_image_files)

# 🔥 FILTROWANIE BAZY: Zostawiamy tylko te pliki, których NIE MA w checkpoincie
image_files_to_process = [f for f in base_image_files if f not in processed_source_files]
skipped_count = total_images - len(image_files_to_process)

# ✍️ Otwieramy manifest w trybie 'a' (Append). Nowe rekordy będą dopisywane na końcu pliku
manifest_file = open(MANIFEST_PATH, 'a', encoding='utf-8', buffering=1)

pipeline_start = time()
written = 0

print(f"📊 Status: Razem zdjęć: {total_images} | Pominięto (zrobione): {skipped_count} | Do przetworzenia: {len(image_files_to_process)}")
print('=' * 60)

# Główna pętla wykonuje się wyłącznie dla brakujących plików
for current_idx, filename in enumerate(image_files_to_process, start=skipped_count + 1):
    img_path = os.path.join(INPUT_DIR, filename)
    source_hash = hashlib.sha1(filename.encode()).hexdigest()
    source_id = source_hash[:12]

    coords_tracker = []
    
    # Wywołanie poprawionej funkcji
    split = get_split(filename)
    out_subdir = os.path.join(OUTPUT_DIR, split) 
    
    rng = random.Random(int(source_id, 16) & 0xFFFFFFFF)

    elapsed_so_far = time() - pipeline_start
    print(f'[{current_idx}/{total_images}] 📷 {filename} | Split: {split} | Czas sesji: {elapsed_so_far:.0f}s')

    try:
        raw_pil = load_base_image(img_path)
        raw_pil.thumbnail((1024, 1024), Image.LANCZOS)
        raw_full_size = list(raw_pil.size)

        for sf in SCALE_FACTORS:
            for pair in ALGORITHM_PAIRS:

                pair_id = pair['pair_id']

                actual_sf = 1 if pair_id == 0 else sf
                
                # Generujemy CTRL tylko przy pierwszym obiegu pętli SCALE_FACTORS
                if pair_id == 0 and sf != SCALE_FACTORS[0]:
                    continue
                
                t0 = time()

                if split in ('test', 'stress_test') and pair_id == EXCLUDED_PAIR_FROM_TEST:
                    continue

                # KROK A: Przetwarzanie CAŁEGO obrazu poprzez degradacje i super-rozdzielczość
                low_res_full = pair['downscale'](raw_pil, sf)
                high_res_full = pair['upscale'](low_res_full, sf)

                # KROK B: Smart Crop (wyszukiwanie optymalnego wycinka o wysokiej entropii)
                crop_info = smart_crop(
                    high_res_full, 
                    crop_size=CROP_SIZE,
                    n_candidates=N_CANDIDATES, ent_min=ENTROPY_MIN, 
                    noise_var_max=NOISE_VAR_MAX, rng=rng
                )

                patch_256 = crop_info['patch_pil']
                x, y = crop_info['top_left_xy']
                coords_tracker.append((x, y))

                # KROK C: Center Crop
                result_256 = center_crop(high_res_full, x, y, CROP_SIZE)

                # KROK D: ZAPIS NA DYSK LOKALNY
                sample_id = f'{source_id}_p{pair_id}_s{sf}'
                out_filename = f'{sample_id}.png'
                out_path = os.path.join(out_subdir, out_filename)
                
                # Zabezpieczenie: jeśli plik graficzny fizycznie już tam jest, nie nadpisujemy go
                if not os.path.exists(out_path):
                    result_256.save(out_path, 'PNG') 

                elapsed = time() - t0
                up_method = pair['upscale_method'](sf) if callable(pair['upscale_method']) else pair['upscale_method']

                # Budowa słownika z metadanymi próbki
                entry = {
                    'sample_id': sample_id,
                    'source_image_id': source_id,
                    'source_file': filename,
                    'source_full_size_px': raw_full_size,
                    'split': split,
                    'is_stress_test': split == 'stress_test',
                    'pair_id': pair_id,
                    'degradation': {
                        'downscale': {'name': pair['down_name'], 'abbr': pair['down_abbr']},
                        'upscale':   {'name': pair['up_name'],   'abbr': pair['up_abbr'], 'method': up_method},
                        'scale_factor': sf
                    },
                    'crop': {
                        'size_px': CROP_SIZE,
                        'top_left_xy': [x, y],
                        'entropy_bits': round(crop_info['entropy'], 4),
                        'noise_var_laplacian': round(crop_info['noise_var'], 2),
                        'fallback_used': crop_info['fallback_used']
                    },
                    'file': {
                        'path_relative': f'{split}/{out_filename}',
                        'format': 'PNG',
                        'size_bytes': os.path.getsize(out_path) if os.path.exists(out_path) else 0
                    }
                }
                
                # Natychmiastowy zapis linii JSONL na dysk
                manifest_file.write(json.dumps(entry, ensure_ascii=False) + '\n')
                written += 1
                
        stats = Counter(coords_tracker)
        duplicates = {k: v for k, v in stats.items() if v > 1}
        
        if duplicates:
            print(f"   ⚠️ Powtórzenia cropów dla {filename}:")
            for loc, count in duplicates.items():
                print(f"      - Lokalizacja {loc}: wybrana {count} razy")
        else:
            print(f"   ✅ Wszystkie wycinki ({len(coords_tracker)}) dla tego zdjęcia są unikalne.")
            
    except Exception as exc:
        print(f'   ❌ Błąd przetwarzania {filename}: {exc}')
        import traceback; traceback.print_exc()
        
    finally:
        # Czyszczenie pamięci RAM i VRAM po każdym obrazie bazowym
        for var in ('raw_pil', 'low_res_full', 'high_res_full', 'patch_320', 'result_256', 'patch_256'):
            if var in locals():
                del locals()[var]
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

# --- ZAMKNIĘCIE STRUMIENI ZAPISU ---
manifest_file.flush()
try:
    os.fsync(manifest_file.fileno()) # Opróżnienie buforów systemowych na dysk EXT4
except:
    pass
manifest_file.close()

total_time = time() - pipeline_start
print('\n' + '=' * 60)
print(f'🏁 Przetwarzanie ukończone!')
print(f'   Pominięto (z checkpointu) : {skipped_count}')
print(f'   Przetworzono nowo         : {current_idx - skipped_count if "current_idx" in locals() else 0}')
print(f'   Zapisanych nowych rekordów: {written}')
print(f'   Czas całkowity sesji      : {total_time:.1f}s ({total_time/60:.1f} min)')
print(f'   📂 Wszystkie pliki zostały bezpiecznie zapisane w {OUTPUT_DIR}')
print('=' * 60)

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

def run_sanity_check_grid(mode='dynamic'):
    """
    mode: 'frozen'  - wszystkie warianty używają tych samych współrzędnych z oryginału.
          'dynamic' - każdy wariant wywołuje smart_crop niezależnie (tak jak w pipeline).
    """
    # 1. Pobranie zdjęcia
    image_files = sorted([f for f in os.listdir(INPUT_DIR) if f.lower().endswith(extensions)])
    if not image_files:
        print("🚨 Brak obrazów!")
        return
        
    test_img_path = os.path.join(INPUT_DIR, image_files[0])
    print(f"📷 Sanity Check ({mode} mode) na: {image_files[0]}")
    
    raw_pil = load_base_image(test_img_path)
    raw_pil.thumbnail((1024, 1024), Image.LANCZOS)
    
    # 2. Jeśli tryb 'frozen', ustalamy współrzędne raz na początku
    frozen_xy = None
    if mode == 'frozen':
        crop_info = smart_crop(
            raw_pil, crop_size=CROP_SIZE,
            n_candidates=N_CANDIDATES, ent_min=ENTROPY_MIN, 
            noise_var_max=NOISE_VAR_MAX, rng=random.Random(42)
        )
        frozen_xy = crop_info['top_left_xy']
        print(f"📍 Zamrożone współrzędne: {frozen_xy}")

    # 3. Przygotowanie siatki
    n_rows = len(ALGORITHM_PAIRS)
    n_cols = len(SCALE_FACTORS)
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 5 * n_rows))
    fig.suptitle(f"Sanity Check: {image_files[0]} | Mode: {mode}", fontsize=16, y=1.02)
    
    if n_rows == 1 and n_cols == 1: axes = [[axes]]
    elif n_rows == 1: axes = [axes]
    elif n_cols == 1: axes = [[ax] for ax in axes]

    # 4. Pętla generująca
    for row_idx, pair in enumerate(ALGORITHM_PAIRS):
        for col_idx, sf in enumerate(SCALE_FACTORS):
            
            # Proces degradacji
            low_res = pair['downscale'](raw_pil, sf)
            high_res = pair['upscale'](low_res, sf)
            
            # --- LOGIKA WYBORU FRAGMENTU ---
            if mode == 'frozen':
                x, y = frozen_xy
                # W trybie zamrożonym po prostu tniemy
                patch = high_res.crop((x, y, x + CROP_SIZE, y + CROP_SIZE))
                info_text = f"Coord: {x},{y}"
            else:
                # W trybie dynamicznym pozwalamy smart_crop zadziałać na zdegradowanym obrazie
                # Używamy stałego seeda dla powtarzalności testu, ale innego dla każdego sf/pair
                test_rng = random.Random(f"{row_idx}_{col_idx}")
                crop_info = smart_crop(
                    high_res, crop_size=CROP_SIZE,
                    n_candidates=N_CANDIDATES, ent_min=ENTROPY_MIN,
                    noise_var_max=NOISE_VAR_MAX, rng=test_rng
                )
                x, y = crop_info['top_left_xy']
                patch = crop_info['patch_pil']
                # Dodajemy info o entropii, żeby widzieć dlaczego to wybrał
                info_text = f"Coord: {x},{y}\nEnt: {crop_info['entropy']:.2f}"

            # Wizualizacja
            ax = axes[row_idx][col_idx]
            ax.imshow(patch)
            
            title = f"[{pair['pair_id']}] {pair['up_abbr']} (x{sf})\n{info_text}"
            ax.set_title(title, fontsize=10)
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# --- PRZYKŁADY UŻYCIA ---

# 1. Porównaj jakość algorytmów na TYM SAMYM detalu:
run_sanity_check_grid(mode='dynamic')

# 2. Sprawdź, co pipeline faktycznie wybierze do zbioru danych:
# run_sanity_check_grid(mode='dynamic')
